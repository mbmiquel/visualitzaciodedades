# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joypy

colors = ["#FF0000", "#FF7F00", "#FFFF00", "#00FF00", "#0000FF", "#4B0082", "#9400D3", "#8B4513", "#FF4500", "#FF69B4", "#00CED1", "#808080"]
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# %%
df_data = pd.read_csv("temperaturesbarcelonadesde1780.csv")
df_data
# Out:
#       Any  Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc
# 0    1780                 6.7                  7.3               11.6  \
# 1    1781                 7.5                  8.9               10.9
# 2    1782                 8.2                  6.1                9.8
# 3    1783                 8.3                  8.6                9.6
# 4    1784                 7.3                  7.1               10.8
# ..    ...                 ...                  ...                ...
# 238  2018                10.5                  6.7               10.8
# 239  2019                 8.1                 11.9               13.5
# 240  2020                10.0                 12.8               11.9
# 241  2021                 7.7                 11.6               12.1
# 242  2022                10.2                 11.8               10.8
#
#      Temp_Mitjana_Abril  Temp_Mitjana_Maig  Temp_Mitjana_Juny
# 0                  11.4               16.3               19.1  \
# ...

# %%
df_data = df_data.rename(columns={"Temp_Mitjana_Gener": "Gener",
                         "Temp_Mitjana_Febrer": "Febrer",
                         "Temp_Mitjana_Marc": "Marc",
                         "Temp_Mitjana_Abril": "Abril",
                         "Temp_Mitjana_Maig": "Maig",
                         "Temp_Mitjana_Juny": "Juny",
                         "Temp_Mitjana_Juliol": "Juliol",
                         "Temp_Mitjana_Agost": "Agost",
                         "Temp_Mitjana_Setembre": "Setembre",
                         "Temp_Mitjana_Octubre": "Octubre",
                         "Temp_Mitjana_Novembre": "Novembre",
                         "Temp_Mitjana_Desembre": "Desembre"})
df_data = df_data.drop('Any', axis=1)

# %%
fig, ax = joypy.joyplot(df_data, color = colors,  fade = True)
